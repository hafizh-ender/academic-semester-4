# %%
import pandas as pd
import matplotlib.pyplot as plt

fivehz = pd.read_csv('5hz.csv')
sixhz = pd.read_csv('6hz.csv')
sevenhz = pd.read_csv('7hz.csv')

fivehz
# Out:
#        X--Trace 1::[CH1]  Y--Trace 1::[CH1]
# 0              -1.000000          -0.092798
# 1              -0.999938          -0.099256
# 2              -0.999875          -0.096027
# 3              -0.999812          -0.096027
# 4              -0.999750          -0.099256
# ...                  ...                ...
# 31997           0.999813          -0.092798
# 31998           0.999875           0.049261
# 31999           0.999938          -0.089570
# 32000           1.000000          -0.086341
# 32001           1.000063          -0.092798
#
# [32002 rows x 2 columns]

# %%
xfive = fivehz['X--Trace 1::[CH1]']
yfive = fivehz['Y--Trace 1::[CH1]']

plt.plot(xfive, yfive)

plt.xlim(-1, 1)
plt.ylim(-3.5, 3.5)

plt.xlabel("Time (200 ms)")
plt.ylabel("Voltage (V)")
# Out:
# Text(0, 0.5, 'Voltage (V)')

# %%
xsix = sixhz['X--Trace 1::[CH1]']
ysix = sixhz['Y--Trace 1::[CH1]']

plt.plot(xsix, ysix)

plt.xlim(-1, 1)
plt.ylim(-3.5, 3.5)

plt.xlabel("Time (200 ms)")
plt.ylabel("Voltage (V)")
# Out:
# Text(0, 0.5, 'Voltage (V)')

# %%
xseven = sevenhz['X--Trace 1::[CH1]']
yseven = sevenhz['Y--Trace 1::[CH1]']

plt.plot(xseven, yseven)

plt.xlim(-1, 1)
plt.ylim(-3.5, 3.5)

plt.xlabel("Time (200 ms)")
plt.ylabel("Voltage (V)")
# Out:
# Text(0, 0.5, 'Voltage (V)')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8fecd68d-9d76-4735-b931-836a3c2078b8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
