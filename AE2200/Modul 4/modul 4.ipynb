# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rc('text', usetex=True)
plt.rcParams.update({
    'text.usetex' : True,
    # 'font.family' : "Times"
    'font.family' : "serif"
})

fivehz = pd.read_csv('5hz.csv')
sixhz = pd.read_csv('6hz.csv')
sevenhz = pd.read_csv('7hz.csv')

fivehz
# Out:
#        X--Trace 1::[CH1]  Y--Trace 1::[CH1]
# 0              -1.000000          -0.092798
# 1              -0.999938          -0.099256
# 2              -0.999875          -0.096027
# 3              -0.999812          -0.096027
# 4              -0.999750          -0.099256
# ...                  ...                ...
# 31997           0.999813          -0.092798
# 31998           0.999875           0.049261
# 31999           0.999938          -0.089570
# 32000           1.000000          -0.086341
# 32001           1.000063          -0.092798
#
# [32002 rows x 2 columns]

# %%
xfive = (fivehz['X--Trace 1::[CH1]'] + 1) * 200
yfive = fivehz['Y--Trace 1::[CH1]']

plt.plot(xfive, yfive, linewidth=1)

plt.xlim(0, 400)
plt.ylim(-3.5, 3.5)

plt.xlabel("Waktu (ms)")
plt.ylabel("Voltase (V)")

plt.grid(True, linewidth=0.5)

plt.title("Sensor Piezoelektrik, $f = 5\ \mathrm{Hz}$")
# Out:
# Text(0.5, 1.0, 'Sensor Piezoelektrik, $f = 5\\ \\mathrm{Hz}$')

# %%
xsix = (sixhz['X--Trace 1::[CH1]'] + 1) * 200
ysix = sixhz['Y--Trace 1::[CH1]']

plt.plot(xsix, ysix, linewidth=1)

plt.xlim(0, 400)
plt.ylim(-3.5, 3.5)

plt.xlabel("Waktu (ms)")
plt.ylabel("Voltase (V)")

plt.grid(True, linewidth=0.5)

plt.title("Sensor Piezoelektrik, $f = 6\ \mathrm{Hz}$")
# Out:
# Text(0.5, 1.0, 'Sensor Piezoelektrik, $f = 6\\ \\mathrm{Hz}$')

# %%
xseven = (sevenhz['X--Trace 1::[CH1]'] + 1) * 200
yseven = sevenhz['Y--Trace 1::[CH1]']

plt.plot(xseven, yseven, linewidth=1)

plt.xlim(0, 400)
plt.ylim(-3.5, 3.5)

plt.xlabel("Waktu (ms)")
plt.ylabel("Voltase (V)")

plt.grid(True, linewidth=0.5)

plt.title("Sensor Piezoelektrik, $f = 7\ \mathrm{Hz}$")
# Out:
# Text(0.5, 1.0, 'Sensor Piezoelektrik, $f = 7\\ \\mathrm{Hz}$')
